# %% [markdown]
# # Assignment 3:
#
# **Course:** 4DT907 - Project in Data Intensive Systems
# **Date:** 2026-02-11
# **Team:** Samuel, Nasser, Emil, Jesper

# %% [markdown]
# ## 1. ML
#
# ### Iteration 1: Random Forest Classifier (The Baseline)
# **Test:** Established a baseline using RandomForestClassifier().
#
# **Results:**
# - **F1 Mean:** 0.5897942056064062
# - **F1 Std:** 0.018539825082461315
# - **Observation:** Had some trouble classifying rightarmfallforward and leftarmfallforward.
#
# #### Images
# ![BaseLineB](img/BaseLineBox.png)
# ![BaseLineM](img/BaseLineMatrix.png)
#
# **Test:** Trying different parameters for RandomForestClassifier.
#
# **Results:**
# - **F1 Mean:** 0.5942669866732416
# - **F1 Std:** 0.03404205020261337
# - **Observation:** Had some trouble classifying rightarmfallforward and leftarmfallforward.
#
# #### Images
# ![BaseLineB](img/RFCBox.png)
# ![BaseLineM](img/RFCMatrix.png)
#
# [Link to experiment](https://dagshub.com/SamuelFredricBerg/4dt907/experiments#/experiment/m_f8ee81f713e1403f8a4e2b1a30c70873)
#
# ---
#
# ### Iteration 2: Logistic Regression
# **Test:** Applied Logistic regression
#
# **Results:**
# - **F1 Mean:** 0.5344311424317592
# - **F1 Std:** 0.02591865717077767
# - **Observation:** Lower mean as well as std.
#
# ---
#
# ### Iteration 3: Gradient Boosting Classifier (GBC)
# **Test:** Testing to use Gradient Boosting Classifier.
#
# **Explanation:** This uses **Boosting**. Each tree is built to correct the specific classification errors (residuals) of the previous tree.
#
# **Results:**
# - **F1 Mean:** 0.5984886510658025
# - **F1 Std:** 0.030331749201278613
# - **Observation:** Slightly better mean but higher std than the RFC.
#
# #### Images
# ![BaseLineB](img/BestBox.png)
# ![BaseLineM](img/BestMatrix.png)
#
# [Link to experiment](https://dagshub.com/SamuelFredricBerg/4dt907/experiments#/experiment/m_7778333fd6a244bc95545194ee5e4213)
#
# ---
#
# ### Iteration 4: ETC and Naive Baysian
# **Test:** Tested other models.
#
# **Result:** Did not improve f1 at all only reached about 0,45 for ETC and Nive Baysian about 0,3.
#
# #### Images
# ![ETCB](img/ETCBox.png)
# ![ETCM](img/ETCMatrix.png)
#
# [Link to experiment](https://dagshub.com/SamuelFredricBerg/4dt907/experiments#/experiment/m_595b201a379c4088a0cd7d0098e1146e)
#
# ---
#
# ### Final Metric Comparison
# | Variant | Strategy | F1 Mean | Stability (Std) |
# | :--- | :--- | :--- | :--- |
# | **Iter 1** | RFC-Base | 0.5897942056064062 | 0.018539825082461315 |
# | **Iter 1.2** | RFC | 0.5942669866732416 | 0.03404205020261337 |
# | **Iter 2** | Linear (LogReg) | 0.5344311424317592 | 0.02591865717077767 |
# | **Iter 3** | Boosting (GBC) | 0.5984886510658025 | 0.030331749201278613 |
# | **Iter 4** | ETC | 0.31659271303284436 | 0.03152777445702387 |
#
#
# ![Histogram](img/newplot.png)

# %% [markdown]
# ## 2. Dependency Management
#
# Currently the dependencies are managed by requirements.txt for the backend and ML training and by package.json and package-lock.json for the frontend. This currently encompasses all of the dependencies for the project.
#
# Regarding updates to the dependencies themselves, we do not expect them to be majorly changed due to using older language versions and therefore only expect minor or security updates. Possible impovement to this would be to setup dependabot for our github repository to automatically check for updates and create pull requests for them.
