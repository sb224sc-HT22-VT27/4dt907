# %% [markdown]
# # Assignment 5:
#
# **Course:** 4DT907 - Project in Data Intensive Systems
# **Date:** 2026-02-18
# **Team:** Samuel, Nasser, Emil, Jesper

# %% [markdown]
# ## ML
#
# We began to introduce ensemble to further imprive the result of the two models.

# %% [markdown]
# ### Regression model/A2
# For A2 we chose stacking as it could combine all of our different models and utilize the strengths and weakness of the different ones.
#
# We first tried without the level 1 model actually getting the data but only the results form the level 0 models. This did not increase the r2 neither gave a p<0.05 making it not significantly better. The visual compaiosn although was quite interesting.
#
# ![Visuals](EnsembleComp.png)
# ![Visuals](Ensemblepval.png)

# %% [markdown]
# ### Classification model/A3
