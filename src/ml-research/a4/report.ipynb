# %% [markdown]
# # Assignment 4:
#
# **Course:** 4DT907 - Project in Data Intensive Systems
# **Date:** 2026-02-18
# **Team:** Samuel, Nasser, Emil, Jesper

# %% [markdown]
# ## ML

# %% [markdown]
# ### Comparison of models
# Added an artifact of the CV scores that saves into DagsHub.
#
# T-test of k-fold CV:
#
# Into ml_utils.py we added a method that gets the @prod CV scores and compares them to the current model trained. This makes a plot for visual check aswell as the mean diff in R2 and the p-value to check if its a significant change.
#
# It also compares the statistical confidence between latest test, dev and prod.
#
# #### Example of training where the result was worse than prod and dev
#
# ![Plot](challenger_vs_prod_ttest.png)
#
# ![Plot](model_confidence_comparison.png)

# %% [markdown]
# ### Assignment 2 improvement
# Added Lasso to already existing logic to try and improve the result.
#
# Using standardscaler and polynomial features inside a pipeline with the LassoCV this rendered in a new champion.
# Results:
# - R2_Mean: **0.7728491119724374**
# - R2_Std: **0.018052259139434895**
# - MAE_Mean: **0.08013486562024422**
# - MAE_Std: **0.003272729898490268**
# - MSE_Mean: **0.010827085456267357**
# - MSE_Std: **0.0007984021378534678**
#
# [LinkToExperiment](https://dagshub.com/SamuelFredricBerg/4dt907/experiments#/experiment/m_14e6d24beb2546f9af242d4996dca891)

# %% [markdown]
# Application is now deployed with vercel and this process has been integrated into the CI/CD pipeline. The application is accessible at [https://4dt907.vercel.app/](https://4dt907.vercel.app/).
#
# Added a dependabot for dependecy updates and security patches. This will automatically create PRs when there are updates available for the dependencies used in the project.
#
# The remaining DevOps/QA tasks have been active in the projext since earlier sprints, things such as testing, design principels, naming conventions, code structure and CI/CD pipeline have been in place since the beginning of the project and have been continuously improved throughout the sprints.
#
# One part that has not been significantly improved during this sprint is the documentation due to time constraints and therefore has been prioritized for the next sprint. The documentation will be updated to include more details about the implementation, usage instructions, and any other relevant information that can help users understand and utilize the project effectively.
