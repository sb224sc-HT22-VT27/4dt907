# %% [markdown]
# # Assignment 8
#
# **Course:** 4DT907 - Project in Data Intensive Systems
# **Date:** 2026-04-22
# **Team:** Samuel, Nasser, Emil, Jesper

# %% [markdown]
# ## ML-Report

# %% [markdown]
# ### Refactor faults from prevoius assignment
#
# #### Problem
# The way we handled sequences was that we took frames 1-30 then 2-31 and so on. This made the test data be almost identical as the training data, impacting the results.
#
# #### Fix (80/10/10)
# We fixed this by instead of separating the test data as sequences we separated 10 % of files which was not used for training and saved only for testing.

# %% [markdown]
# ### New Results
# We tested several different hyperparamters but these where the 2 noticable experiments as the best and first.
# #### New Baseline
# New average error: 3.241190501459511 cm
#
# ### y-Mirroring data augmentation and 256 hidden
# Total Files: 358 (179)
# Test Files 35
# Val Files:  70
# Train Files: 218
#
# ![img](img/improved.png)
# New Average Error: 2.638 cm
# Std Deviation: 1.799
#
# One random test:
#
#
# ```markdown
# ======================================================================
# Joint Name         | Pred Z (m)   | True Z (m)   | Diff (cm)
# ----------------------------------------------------------------------
# nose               |    -0.1378   |    -0.1304   |     0.74 cm
# left_shoulder      |    -0.0411   |    -0.0559   |     1.48 cm
# left_elbow         |     0.0013   |    -0.0034   |     0.47 cm
# right_shoulder     |    -0.2020   |    -0.1965   |     0.54 cm
# right_elbow        |     0.0057   |    -0.0032   |     0.89 cm
# left_wrist         |    -0.0981   |    -0.1204   |     2.23 cm
# right_wrist        |     0.0107   |    -0.0055   |     1.63 cm
# left_hip           |    -0.1098   |    -0.1041   |     0.57 cm
# right_hip          |     0.0005   |    -0.0140   |     1.45 cm
# left_knee          |    -0.0013   |     0.0034   |     0.48 cm
# right_knee         |    -0.1703   |    -0.1639   |     0.63 cm
# left_ankle         |     0.0198   |     0.0112   |     0.87 cm
# right_ankle        |    -0.0424   |    -0.0665   |     2.41 cm
# ----------------------------------------------------------------------
# Average Frame Error: 1.11 cm
# ======================================================================
# ```

# %% [markdown]
# ### Software
#
# 3D visualiztion of the movement has been implemented and functions, but changes will be held in develop branch util next week for code quality and technical debt reasons.
#
# The MediaPipe accuracy vs Ground truth has been implemented as a script as there seemingly being no reason to add it to the deployed application and more of a validation tool of the MediaPipe model.
