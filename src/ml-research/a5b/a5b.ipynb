# %% [markdown]
# # Assignment 5b:
#
# **Course:** 4DT907 - Project in Data Intensive Systems
# **Date:** 2026-03-04
# **Team:** Samuel, Nasser, Emil, Jesper

# %% [markdown]
# ## ML

# %% [markdown]
# ### Tuning of models
#
# Tested different hyperparameters for A2 and A3 but found no significant improvement to any of the models. Tested different tree-based classifiers inside our stacking ensembles.

# %% [markdown]
# ### Prepared for next sprint
#
# We have been preparing for the next sprint with SVMs and how we could implement into our stacking ensemble.

# %% [markdown]
# ### Retroactive review
#
# Review what we have done so far and looked for faults, mistakes and possible improvements to improve code base and documentation in the next Retroactive sprint.
